# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("Global_Youtube_Statistics.csv", encoding="latin1")
data.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
data.tail(10)
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 985   986                      TKOR     12400000  3.392023e+09
# 986   987                 ANNA KOVA     12400000  1.395959e+10
# 987   988             Avril Lavigne     12400000  6.202090e+09
# 988   989                    Caylus     12400000  4.779140e+09
# 989   990                 Migos ATL     12400000  6.993406e+09
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 985       Education                      TKoR        0             NaN
# 986  People & Blogs                  annakova        1             NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %% [markdown]
# # DESCRIPCIÓN DE LOS DATOS

# %%
data.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(data.select_dtypes('O'))

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(data.select_dtypes('number'))
# Out:
#                                          count          mean        median  \
# rank                                     995.0  4.980000e+02  4.980000e+02
# subscribers                              995.0  2.298241e+07  1.770000e+07
# video views                              995.0  1.103954e+10  7.760820e+09
# uploads                                  995.0  9.187126e+03  7.290000e+02
# video_views_rank                         994.0  5.542489e+05  9.155000e+02
# country_rank                             879.0  3.860535e+02  5.100000e+01
# channel_type_rank                        962.0  7.457193e+02  6.550000e+01
# video_views_for_the_last_30_days         939.0  1.756103e+08  6.408500e+07
# lowest_monthly_earnings                  995.0  3.688615e+04  1.330000e+04
# highest_monthly_earnings                 995.0  5.898078e+05  2.127000e+05
# lowest_yearly_earnings                   995.0  4.422574e+05  1.595000e+05
# ...

# %%
data.isna().sum().sort_values(ascending = False)
# Out:
# subscribers_for_last_30_days               337
# Longitude                                  123
# Latitude                                   123
# Urban_population                           123
# Unemployment rate                          123
# Population                                 123
# Gross tertiary education enrollment (%)    123
# Country                                    122
# Abbreviation                               122
# country_rank                               116
# video_views_for_the_last_30_days            56
# category                                    46
# channel_type_rank                           33
# channel_type                                30
# created_date                                 5
# created_month                                5
# created_year                                 5
# video_views_rank                             1
# rank                                         0
# highest_yearly_earnings                      0
# ...

# %% [markdown]
# Piensa de que de 955 datos, los subcriptores en los ultimos 30 días no tienen datos más del 30%. Por lo que se puede eliminar esa variable

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory analysis

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option("display.float_format", "{:.2f}".format)

# %%
category_subscribers_mean = data.groupby("category")["subscribers"].mean()
category_subscribers_mean = category_subscribers_mean.sort_values(ascending=False)

# %%
category_subscribers_mean.plot(kind="bar")
plt.title("mean Subscribers by Category")
plt.xlabel("category")
plt.ylabel("mean Subscribers")
plt.xticks(rotation = 90)
plt.show()

# %%
channel_type_counts = data["channel_type"].value_counts()
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.head(5).plot(kind = "pie", autopct = "%1.1f%%")
plt.title("Channel Type Distribution")
plt.ylabel("")
plt.show()

# %%
plt.scatter(data["subscribers"], data["video views"])
plt.title("Svcatter plot of subscribers  vs. video views")
plt.xlabel("Subscribers")
plt.ylabel("Video Views")
plt.show()

# %%
country_subscribers_total = data.groupby("Country")["subscribers"].sum().sort_values(ascending=False)
country_subscribers_total
# Out:
# Country
# United States           7329500000
# India                   4310600000
# Brazil                  1221800000
# United Kingdom           917400000
# Mexico                   626900000
# Indonesia                534100000
# South Korea              481700000
# Russia                   407200000
# Thailand                 386500000
# Spain                    385100000
# Canada                   363900000
# Argentina                328500000
# Colombia                 264500000
# Philippines              240100000
# Japan                    189100000
# Saudi Arabia             179100000
# Australia                172000000
# Pakistan                 155400000
# United Arab Emirates     148200000
# Ukraine                  125600000
# Germany                  116400000
# Turkey                    91600000
# Chile                     87200000
# France                    83900000
# Jordan                    67000000
# Sweden                    63000000
# ...

# %%
country_subscribers_total.head(10).plot(kind = "bar")
plt.title("Total Subscribers by Country")
plt.xlabel("Country")
plt.ylabel("Total Subscribers")
plt.xticks(rotation = 90)
plt.show()

# %%
data.groupby("created_year")["subscribers"].mean().sort_values(ascending=True)
# Out:
# created_year
# 2022.00   13640000.00
# 2021.00   18573913.04
# 2019.00   18639393.94
# 2017.00   18666176.47
# 2014.00   20618367.35
# 2010.00   20670833.33
# 2015.00   21247945.21
# 2020.00   21350000.00
# 2011.00   21800000.00
# 2018.00   23060869.57
# 2016.00   23101298.70
# 2009.00   23105769.23
# 2008.00   23652173.91
# 2012.00   24038235.29
# 2013.00   24527631.58
# 2007.00   24902040.82
# 2005.00   25829166.67
# 2006.00   31884615.38
# 1970.00   36300000.00
# Name: subscribers, dtype: float64

# %%
pd.set_option("display.float_format", "{:.0f}".format)

# %%
data.groupby("channel_type")["video_views_rank"].median().sort_values(ascending=False)
# Out:
# channel_type
# Autos           3468229
# Tech               2420
# Games              1944
# People             1868
# Howto              1574
# Nonprofit          1538
# Sports             1186
# Comedy             1033
# Film                880
# Entertainment       796
# News                612
# Education           538
# Music               385
# Animals             136
# Name: video_views_rank, dtype: float64

# %%
data.groupby("Country")["subscribers_for_last_30_days"].max().sort_values(ascending=False)
# Out:
# Country
# United States          8000000
# Indonesia              5500000
# United Arab Emirates   3400000
# South Korea            3200000
# Sweden                 3000000
# Turkey                 2100000
# India                  2000000
# Italy                  2000000
# Argentina              1900000
# Russia                 1600000
# Colombia               1600000
# Pakistan               1300000
# Kuwait                 1300000
# Latvia                 1200000
# Japan                  1100000
# Brazil                 1100000
# Germany                 900000
# Spain                   800000
# United Kingdom          600000
# Mexico                  600000
# Australia               600000
# Chile                   500000
# Philippines             500000
# Saudi Arabia            500000
# Canada                  400000
# Thailand                300000
# Jordan                  300000
# Ecuador                 300000
# Ukraine                 230000
# Singapore               200000
# ...

# %%
data.groupby("created_month")["subscribers"].sum()
# Out:
# created_month
# Apr    1581200000
# Aug    1813600000
# Dec    1577300000
# Feb    1533800000
# Jan    2254600000
# Jul    1922300000
# Jun    1846400000
# Mar    2320500000
# May    1997700000
# Nov    1930200000
# Oct    1503700000
# Sep    2496200000
# Name: subscribers, dtype: int64

# %%
data.groupby("category")["video views"].std()
# Out:
# category
# Autos & Vehicles         2964425984
# Comedy                   6406251669
# Education               25572139026
# Entertainment           10128204611
# Film & Animation        10899550881
# Gaming                   5835933598
# Howto & Style            4300326961
# Movies                   3353301875
# Music                   17782784424
# News & Politics          5165961805
# Nonprofits & Activism    2698145850
# People & Blogs          12510420847
# Pets & Animals           6475165093
# Science & Technology     2937981619
# Shows                   43723894662
# Sports                  21703831459
# Trailers                 1382496086
# Travel & Events                 NaN
# Name: video views, dtype: float64

# %%
data.groupby("Country")["Unemployment rate"].min().sort_values(ascending=True)
# Out:
# Country
# Thailand                 1
# Cuba                     2
# Vietnam                  2
# Philippines              2
# Kuwait                   2
# Japan                    2
# United Arab Emirates     2
# Germany                  3
# Netherlands              3
# Peru                     3
# Malaysia                 3
# Mexico                   3
# United Kingdom           4
# Ecuador                  4
# El Salvador              4
# Singapore                4
# South Korea              4
# Bangladesh               4
# China                    4
# Pakistan                 4
# Switzerland              5
# Russia                   5
# Indonesia                5
# Australia                5
# India                    5
# Canada                   6
# Saudi Arabia             6
# Sweden                   6
# Latvia                   7
# Finland                  7
# Chile                    7
# Samoa                    8
# France                   8
# Venezuela                9
# ...

# %%
data.groupby("channel_type")["uploads"].sum()
# Out:
# channel_type
# Animals            42868
# Autos                949
# Comedy             81722
# Education         146355
# Entertainment    3345035
# Film              114654
# Games             399473
# Howto              79417
# Music             424950
# News             3989151
# Nonprofit         205824
# People            117424
# Sports            158995
# Tech               33780
# Name: uploads, dtype: int64

# %%
data.groupby(["Latitude", "Longitude"]).size()
# Out:
# Latitude  Longitude
# -38       -64           13
# -36       -72            3
# -25       134            9
# -14       -52           62
#           -172           1
# -9        -75            1
# -2        -78            2
# -1        114           28
# 1         104            3
# 4         102            1
# 5         -74           11
# 6         -67            1
# 13        122           12
#           -60            1
# 14        -89            1
#           108            3
# 16        101           18
# 21        79           168
# 22        -78            1
# 23        54             7
# 24        -103          33
#           90             1
#           45             9
# 27        31             2
# 29        47             1
# 30        69             6
# 31        36             3
# 32        -7             1
# 33        44             2
# 34        68             1
# 36        104            1
#           128           17
#           138            5
# ...

# %%
sns.boxplot(x = "channel_type", y = "highest_monthly_earnings", data = data)
plt.title("Distribution of Highest Monthly Earning by Channel Type")
plt.xticks(rotation = 90)
plt.show()

# %%
data.groupby(["category", "Country"])["subscribers"].sum().unstack().plot(kind = "bar", stacked = True)
plt.title("Subscribers Breakdown by Category and Country")
plt.xlabel("Category")
plt.ylabel("Total Subscribers")
plt.legend(title = "Country", bbox_to_anchor =(1.05, 1), loc = "upper left")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.scatter(data["Gross tertiary education enrollment (%)"], data["subscribers"], alpha = 0.5)
plt.title("Scatter Plot of Subrcribers vs gross tertiary education enrrollment")
plt.xlabel("Gross tertiary education enrollment")
plt.ylabel("subscribers")
plt.show()

# %%
data.groupby("channel_type")["Unemployment rate"].mean().head().sort_values(ascending=False).plot(kind = "bar")
plt.title("Average unemployment rate by Channel Type")
plt.xlabel("Channel Type")
plt.ylabel("Average Unemployment Rate")
plt.xticks(rotation = 90)
plt.show()

# %%
data.groupby(["created_year", "channel_type"])["subscribers"].mean().unstack().tail().plot(kind = "bar", width = 1)
plt.title("Average Subscribers by created Year and Channel Type")
plt.xlabel("Created year")
plt.ylabel("Average Subscribers")
plt.xticks(rotation = 45)
plt.legend(title = "Channel Type", bbox_to_anchor = (1.05, 1), loc = "upper left")
plt.show()

# %%
data.groupby(["created_year", "created_month"])["subscribers"].sum().unstack().head().plot(kind="area", stacked = True)
plt.title("Subscribers Growth Over Time")
plt.xlabel("Year")
plt.ylabel("Total Subscribers")
plt.legend(title = "Month", bbox_to_anchor = (1.05,1), loc = "upper left")
plt.xticks(rotation = 45)
plt.show()

# %%
data.groupby(["created_year", "Country"])["highest_yearly_earnings"].mean().unstack().head().plot(kind = "line", marker = "o")
plt.title("Trend of highest Yearly Earning by Crated Year and Country")
plt.xlabel("Created Year")
plt.ylabel("Average Highest Yearly Earnings")
plt.legend(title = "Country", bbox_to_anchor = (1.05,1), loc = "upper left")
plt.xticks(rotation = 45)
plt.show()

# %%
category_highest_monthly_earnings_sum = data.groupby("category")["highest_monthly_earnings"].sum()
category_highest_monthly_earnings_sum.sort_values(ascending=False, inplace =True)

# %%
category_highest_monthly_earnings_sum.head().plot(kind = "pie", autopct="%1.1f%%")
plt.title("Percentage of highest Monthly Earnings by Category")
plt.ylabel("")
plt.show()

# %%
channel_created_subscribers_mean = data.groupby(["channel_type", "created_year"])["subscribers_for_last_30_days"].mean().unstack()
channel_created_subscribers_mean
# Out:
# created_year    1970   2005   2006   2007   2008   2009    2010   2011   2012  \
# channel_type
# Animals          NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# Autos            NaN    NaN      2 500000    NaN    NaN     NaN    NaN      9
# Comedy           NaN 400000 100000 100000 200000 400000     NaN  50000    NaN
# Education        NaN    NaN 700000    NaN 200000 100000  200000 200000 350000
# Entertainment 300000 325000 306250 342857 450000 480000  212575 442857 760000
# Film             NaN      1 333333    NaN 100000    NaN     NaN 225008 300000
# Games            NaN 100000    338  50006 100000 200000       3 150000 376923
# Howto            NaN 500000    NaN    NaN    NaN 100000  100000    NaN    NaN
# Music            NaN 160000 433334 146160 185385 153846  175000 158829 200000
# News             NaN 100000 205000 440000 100000 275000  100000    NaN 400000
# Nonprofit        NaN    NaN    NaN    NaN    NaN 100000     NaN    NaN    NaN
# ...

# %%
sns.heatmap(channel_created_subscribers_mean.head(), cmap="YlGnBu", annot = True)
plt.title("Mean subscribers for las 30 days by channel type and created year")
plt.xlabel("created year")
plt.ylabel("channel type")
plt.show()

# %%
data.groupby("created_month")["subscribers_for_last_30_days"].mean().plot(kind = "line", marker = "o")
plt.title("Average suscribers for last 30 days by month")
plt.xlabel("Month")
plt.ylabel("Average suscribers for last 30 days")
plt.xticks(rotation = 45)
plt.show()
