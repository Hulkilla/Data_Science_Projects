# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# En este caso se trata de buscar si hay alguna correlación para saber si te van a conceder o no una tarjeta de crédito
# Esto viene dado por nuestra columna "label" que viene en un csv separado

# %%
data = pd.read_csv("Credit_card.csv")
data.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0        -18772.0         365243             1           0      0         0
# 1        -13557.0           -586             1           1      1         0
# 2             NaN           -586             1           1      1         0
# 3        -13557.0           -586             1           1      1         0
# 4        -13557.0           -586             1           1      1         0
#
#   Type_Occupation  Family_Members
# 0             NaN               2
# 1             NaN               2
# 2             NaN               2
# 3             NaN               2
# 4             NaN               2

# %%
label = pd.read_csv("Credit_card_label.csv")
label.head()
# Out:
#     Ind_ID  label
# 0  5008827      1
# 1  5009744      1
# 2  5009746      1
# 3  5009749      1
# 4  5009752      1

# %%
data = data.merge(label, on = "Ind_ID",how="left")
data.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0        -18772.0         365243             1           0      0         0
# 1        -13557.0           -586             1           1      1         0
# 2             NaN           -586             1           1      1         0
# 3        -13557.0           -586             1           1      1         0
# 4        -13557.0           -586             1           1      1         0
#
#   Type_Occupation  Family_Members  label
# 0             NaN               2      1
# 1             NaN               2      1
# 2             NaN               2      1
# 3             NaN               2      1
# 4             NaN               2      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
#  17  Family_Members   1548 non-null   int64
#  18  label            1548 non-null   int64
# dtypes: float64(2), int64(9), object(8)
# memory usage: 229.9+ KB

# %% [markdown]
# # DESCRIPCIÓN DE LOS DATOS

# %%
data.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# 25%     -3174.500000           1.0     0.000000     0.000000     0.000000
# 50%     -1565.000000           1.0     0.000000     0.000000     0.000000
# 75%      -431.750000           1.0     0.000000     1.000000     0.000000
# max    365243.000000           1.0     1.000000     1.000000     1.000000
#
#        Family_Members        label
# count     1548.000000  1548.000000
# mean         2.161499     0.113049
# std          0.947772     0.316755
# min          1.000000     0.000000
# 25%          2.000000     0.000000
# 50%          2.000000     0.000000
# 75%          3.000000     0.000000
# max         15.000000     1.000000

# %% [markdown]
# Las variable Mobile_Phone no tiene sentido porque todos tienen teléfono móvil --> Eliminar
# Los hijos casi todos son 0, pero si que hay un 25% (superior) que tiene entre 1 y 14

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(data.select_dtypes('O'))

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(data.select_dtypes('number'))
# Out:
#                  count          mean     median            std        min  \
# Ind_ID          1548.0  5.078920e+06  5078841.5   41717.587742  5008827.0
# CHILDREN        1548.0  4.127907e-01        0.0       0.776691        0.0
# Annual_income   1525.0  1.913993e+05   166500.0  113252.997656    33750.0
# Birthday_count  1526.0 -1.604034e+04   -15661.5    4229.503202   -24946.0
# Employed_days   1548.0  5.936469e+04    -1565.0  137808.062701   -14887.0
# Mobile_phone    1548.0  1.000000e+00        1.0       0.000000        1.0
# Work_Phone      1548.0  2.080103e-01        0.0       0.406015        0.0
# Phone           1548.0  3.094315e-01        0.0       0.462409        0.0
# EMAIL_ID        1548.0  9.237726e-02        0.0       0.289651        0.0
# Family_Members  1548.0  2.161499e+00        2.0       0.947772        1.0
# label           1548.0  1.130491e-01        0.0       0.316755        0.0
#
#                        25%        50%         75%        max
# Ind_ID          5045069.75  5078841.5  5115673.00  5150412.0
# CHILDREN              0.00        0.0        1.00       14.0
# Annual_income    121500.00   166500.0   225000.00  1575000.0
# Birthday_count   -19553.00   -15661.5   -12417.00    -7705.0
# Employed_days     -3174.50    -1565.0     -431.75   365243.0
# Mobile_phone          1.00        1.0        1.00        1.0
# Work_Phone            0.00        0.0        0.00        1.0
# Phone                 0.00        0.0        1.00        1.0
# EMAIL_ID              0.00        0.0        0.00        1.0
# Family_Members        2.00        2.0        3.00       15.0
# label                 0.00        0.0        0.00        1.0

# %% [markdown]
# # ELIMINACIÓN DE LOS NULOS

# %%
data.isna().sum().sort_values(ascending = False)
# Out:
# Type_Occupation    488
# Annual_income       23
# Birthday_count      22
# GENDER               7
# Ind_ID               0
# Employed_days        0
# Family_Members       0
# EMAIL_ID             0
# Phone                0
# Work_Phone           0
# Mobile_phone         0
# Housing_type         0
# Marital_status       0
# EDUCATION            0
# Type_Income          0
# CHILDREN             0
# Propert_Owner        0
# Car_Owner            0
# label                0
# dtype: int64

# %% [markdown]
# El tipo de ocupación tiene demasiados NaN (488/1458) --> Hay que eliminarlo

# %%
data.drop(columns = "Type_Occupation", inplace = True)

# %%
data.dropna(inplace = True) #Eliminmos las filas con NaN

# %%
data.isna().sum().sort_values(ascending = False)
# Out:
# Ind_ID            0
# GENDER            0
# Family_Members    0
# EMAIL_ID          0
# Phone             0
# Work_Phone        0
# Mobile_phone      0
# Employed_days     0
# Birthday_count    0
# Housing_type      0
# Marital_status    0
# EDUCATION         0
# Type_Income       0
# Annual_income     0
# CHILDREN          0
# Propert_Owner     0
# Car_Owner         0
# label             0
# dtype: int64

# %%
data.duplicated().sum()
#data.drop_duplicated(inplace = True)
# Out:
# 0

# %%
averageIncome = data["Annual_income"].mean()
averageIncome
# Out:
# 190775.04846256683

# %%
gender_income = data.groupby("GENDER")["Annual_income"].mean()
gender_income.sort_values(ascending=False)
# Out:
# GENDER
# M    222485.245902
# F    172391.840021
# Name: Annual_income, dtype: float64

# %%
sns.barplot(x = gender_income.index, y =gender_income.values)
plt.title("Average Income by Gender")
plt.xlabel("Genders")
plt.ylabel("Money")
plt.show()

# %%
label_counts = data["label"].value_counts()
label_counts
# Out:
# label
# 0    1336
# 1     160
# Name: count, dtype: int64

# %%
plt.pie(label_counts, labels = ["Credic Approved", "Credit Pejected"], autopct="%1.1f%%")
plt.title("Credit Apptoval Status")
plt.show()

# %%
data.groupby("Type_Income")["Annual_income"].mean()
# Out:
# Type_Income
# Commercial associate    233880.169972
# Pensioner               154964.866795
# State servant           210130.434783
# Working                 180154.579974
# Name: Annual_income, dtype: float64

# %%
data.groupby("Marital_status")["Employed_days"].max()
# Out:
# Marital_status
# Civil marriage          365243
# Married                 365243
# Separated               365243
# Single / not married    365243
# Widow                   365243
# Name: Employed_days, dtype: int64

# %%
data.groupby("Housing_type")["Family_Members"].sum()
# Out:
# Housing_type
# Co-op apartment           5
# House / apartment      2900
# Municipal apartment      92
# Office apartment         21
# Rented apartment         46
# With parents            175
# Name: Family_Members, dtype: int64

# %%
data.groupby("GENDER")["Birthday_count"].min() * (-1)
# Out:
# GENDER
# F    24946.0
# M    24662.0
# Name: Birthday_count, dtype: float64

# %%
data.groupby("Propert_Owner")["Annual_income"].mean()
# Out:
# Propert_Owner
# N    183343.352601
# Y    194722.899181
# Name: Annual_income, dtype: float64

# %%
data.groupby("EDUCATION")["Mobile_phone"].max()
# Out:
# EDUCATION
# Academic degree                  1
# Higher education                 1
# Incomplete higher                1
# Lower secondary                  1
# Secondary / secondary special    1
# Name: Mobile_phone, dtype: int64

# %%
data.groupby("CHILDREN")["Annual_income"].sum()
# Out:
# CHILDREN
# 0     191703172.5
# 1      64218600.0
# 2      26226900.0
# 3       2845800.0
# 4        180000.0
# 14       225000.0
# Name: Annual_income, dtype: float64

# %%
sns.boxplot(x="Marital_status", y ="Annual_income", data = data, palette="rainbow")
plt.title("Annual Income Variation by Marital Status")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23352\3496156204.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Marital_status", y ="Annual_income", data = data, palette="rainbow")

# %%
sns.violinplot(x = "GENDER", y = "Birthday_count", data = data, palette="rainbow")
plt.title("Distribution of birthady count by gender")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23352\3376483537.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = "GENDER", y = "Birthday_count", data = data, palette="rainbow")

# %%
data.groupby("Marital_status")["Family_Members"].sum().plot(kind="pie", autopct="%1.1f%%")
plt.title("Family Members Distribution by marital status")
plt.ylabel("")
plt.show()

# %%
data.boxplot(column = "Annual_income", by = "EDUCATION")
plt.title("annual Income Variation by Education Level")
plt.show()

# %%
data = data[["Car_Owner","Propert_Owner", "Annual_income", "EDUCATION", "label"]]

# %%
data
# Out:
#      Car_Owner Propert_Owner  Annual_income                      EDUCATION  \
# 0            Y             Y       180000.0               Higher education
# 1            Y             N       315000.0               Higher education
# 4            Y             N       315000.0               Higher education
# 6            Y             N       315000.0               Higher education
# 7            N             N       180000.0  Secondary / secondary special
# ...        ...           ...            ...                            ...
# 1542         Y             N       360000.0  Secondary / secondary special
# 1544         N             N       225000.0              Incomplete higher
# 1545         Y             Y       180000.0               Higher education
# 1546         Y             N       270000.0  Secondary / secondary special
# 1547         Y             Y       225000.0               Higher education
#
#       label
# 0         1
# 1         1
# 4         1
# 6         1
# 7         1
# ...     ...
# 1542      0
# 1544      0
# 1545      0
# 1546      0
# 1547      0
#
# [1496 rows x 5 columns]

# %% [markdown]
# # Machine Learning

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
data["Car_Owner"] = labelencoder.fit_transform(data["Car_Owner"])
data["Propert_Owner"] = labelencoder.fit_transform(data["Propert_Owner"])
data["EDUCATION"] = labelencoder.fit_transform(data["EDUCATION"])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23352\579257386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Car_Owner"] = labelencoder.fit_transform(data["Car_Owner"])
# C:\Users\USER\AppData\Local\Temp\ipykernel_23352\579257386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Propert_Owner"] = labelencoder.fit_transform(data["Propert_Owner"])
# C:\Users\USER\AppData\Local\Temp\ipykernel_23352\579257386.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["EDUCATION"] = labelencoder.fit_transform(data["EDUCATION"])

# %%
data
# Out:
#       Car_Owner  Propert_Owner  Annual_income  EDUCATION  label
# 0             1              1       180000.0          1      1
# 1             1              0       315000.0          1      1
# 4             1              0       315000.0          1      1
# 6             1              0       315000.0          1      1
# 7             0              0       180000.0          4      1
# ...         ...            ...            ...        ...    ...
# 1542          1              0       360000.0          4      0
# 1544          0              0       225000.0          2      0
# 1545          1              1       180000.0          1      0
# 1546          1              0       270000.0          4      0
# 1547          1              1       225000.0          1      0
#
# [1496 rows x 5 columns]

# %%
x = data.iloc[:,:-1]

# %%
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(x_train)
scaled_X_test = scaler.fit_transform(x_test)

# %%
from sklearn.metrics import accuracy_score

def modelperformance(predictions):
    print("Accuracy score on model is {}".format(accuracy_score(y_test,predictions)))

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()
log_model.fit(scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_predictions =log_model.predict(scaled_X_test)

# %%
modelperformance(log_predictions)
# Out:
# Accuracy score on model is 0.9133333333333333

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.neighbors import KNeighborsClassifier
param_grid={"n_neighbors":  [3,5,7,9,11],
            "weights": ["uniform", "distance"],
            "algorithm": ["auto", "kd_tree"]         
            }

gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv=2)

# %%
gridkn.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'kd_tree'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'uniform'}

# %%
knpreds = gridkn.predict(scaled_X_test)

# %%
modelperformance(knpreds)
# Out:
# Accuracy score on model is 0.9133333333333333

# %%
from sklearn.svm import SVC
svm = SVC()

param_grid_svr ={"C":[0.01,0.1,0.5,1],
                 "kernel": ["linear", "rbf", "poly"]}

gridsvr =GridSearchCV(svm,param_grid_svr)

# %%
gridsvr.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
pred_svc = gridsvr.predict(scaled_X_test)
modelperformance(pred_svc)
# Out:
# Accuracy score on model is 0.9133333333333333

# %%
from sklearn.tree import DecisionTreeClassifier
param_grid = {
    "criterion" : ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None, 10,20,30,40,50],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4]
}

grid_search_tree = GridSearchCV(estimator= DecisionTreeClassifier(), param_grid=param_grid)

# %%
grid_search_tree.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_search_tree.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'min_samples_leaf': 4,
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %%
preds = grid_search_tree.predict(scaled_X_test)
modelperformance(preds)
# Out:
# Accuracy score on model is 0.9033333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()
n_estimators = [32,64,128,256]
max_features = [2,3,4]
bootstrap = [True, False]
oob_score = [True, False]

# %%
param_grid_rfc = {
    "n_estimators":n_estimators,
    "max_features": max_features,
    "bootstrap":bootstrap,
    "oob_score":oob_score
}

# %%
grid_rfc = GridSearchCV(rfc_model, param_grid_rfc)

# %%
grid_rfc.fit(scaled_X_train, y_train)
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py:542: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py", line 1351, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.87459554 0.87459205 0.87542538 0.87375174 0.87543236 0.87710251
#  0.87459205 0.87626569 0.88296025 0.87877964 0.87794282 0.87376569
#  0.87710251 0.87626569 0.87626569 0.88044979 0.87375523 0.86874826
#  0.87628312 0.877106   0.87460948 0.87711646 0.87375872 0.87877615
#         nan 0.88045328        nan 0.87877964        nan 0.88045328
#         nan 0.87961994        nan 0.87794282        nan 0.877106
#         nan 0.877106          nan 0.87877964        nan 0.87375872
#         nan 0.87375872        nan 0.87375872        nan 0.87375872]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256],
#                          'oob_score': [True, False]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 3, 'n_estimators': 32, 'oob_score': True}

# %%
predsrfc=grid_rfc.predict(scaled_X_test)

# %%
modelperformance(predsrfc)
# Out:
# Accuracy score on model is 0.88

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_classifier = AdaBoostClassifier()

ada_param_grid = {
    "n_estimators" : [50, 100, 200],
    "learning_rate" : [0.01,0.1,1,10]
}

ada_grid_search = GridSearchCV(ada_classifier, ada_param_grid, cv = 2)

# %%
ada_grid_search.fit(scaled_X_train, y_train)

# %%
adapred = ada_grid_search.predict(scaled_X_test)

# %%
modelperformance(adapred)
# Out:
# Accuracy score on model is 0.9133333333333333

# %%
from xgboost import XGBClassifier
xgb_Classifier = XGBClassifier()
xgb_param_grid = {
    "n_estimators": [20,40,60,80,100,500,1000,2000,5000],
    "learing_rate": [0.01,0.1,0.2,0.3,0.5,0.7,1],
    "max_depth": [1,3,4,5,7,9]
    }

# %%
xgb_grid_search = Grid
